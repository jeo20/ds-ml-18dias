# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
x = np.linspace(0,10,30)
y = np.sin(x)

# %%
plt.plot(x,y,format);

# %%
plt.plot(x,y,'o');

# %%
aleatorio = np.random.RandomState(0)
marcadores = ['o','x','+','v','s','d']

# %%
for marcador in marcadores:
    plt.plot(aleatorio.rand(5), aleatorio.rand(5), marcador)

# %%
plt.plot(x,y,':ob');

# %%
plt.plot(x,y,'-p');

# %%
plt.plot(x,y,'-p', color ='red');

# %%
plt.plot(x,y,'-p', color ='red', markersize=15);

# %%
plt.plot(x,y,'-p', color ='red', markersize=15, linewidth=4);

# %%
plt.plot(x,y,'-p', color ='red', markersize=15, linewidth=4, markerfacecolor = 'white');

# %%
plt.scatter(x,y);

# %%
aleatorio = np.random.RandomState(0)
plt.scatter(aleatorio.randn(100), aleatorio.randn(100), c=aleatorio.randn(100), s=aleatorio.randn(100)*1000, alpha=0.3, cmap='viridis')
plt.colorbar();
# Out:
# c:\Users\m26344676.SUBINFO\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
