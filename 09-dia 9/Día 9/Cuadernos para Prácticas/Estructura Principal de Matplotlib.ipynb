# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
numeros = [4,2,7,6,3]

plt.plot(numeros);

# %%
# figure es el lienzo
plt.figure(facecolor="orange")
plt.plot(numeros);

# %%
# axes
plt.subplots(ncols=2, nrows=2) # 4 graficos
# Out:
# (<Figure size 640x480 with 4 Axes>,
#  array([[<Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >]], dtype=object))

# %%
fig, axs = plt.subplots(ncols=2, nrows=2)

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %%
type(axs)
# Out:
# numpy.ndarray

# %%
axs[0]
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
axs[0][0]
# Out:
# <Axes: >

# %%
type(axs[0][0])
# Out:
# matplotlib.axes._axes.Axes

# %%
axes1 = axs[0][0]

# %%
axes1.yaxis

# %%
axes1.title()
