# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
df = pd.DataFrame({
    "etiquetas":['Manzanas', 'Bananas', 'Naranjas', 'Uvas'],
    "cantidad":[30, 35, 26, 33]
    })
df
# Out:
#   etiquetas  cantidad
# 0  Manzanas        30
# 1   Bananas        35
# 2  Naranjas        26
# 3      Uvas        33

# %%
fig, axs = plt.subplots(ncols=2, nrows=1)
ax1 = axs[0]
ax2 = axs[1]
ax1.plot(df['etiquetas'], df['cantidad'])
ax2.pie(df['cantidad']);

# %%
plt.style.use('ggplot') #cambia el estilo de todos los graficos

fig, axs = plt.subplots(ncols=2, nrows=1)
ax1 = axs[0]
ax2 = axs[1]
ax1.plot(df['etiquetas'], df['cantidad'])
ax2.pie(df['cantidad']);

# %%
plt.style.use('seaborn-v0_8-pastel') #cambia el estilo de todos los graficos

fig, axs = plt.subplots(ncols=2, nrows=1)
ax1 = axs[0]
ax2 = axs[1]
ax1.plot(df['etiquetas'], df['cantidad'])
ax2.pie(df['cantidad']);

# %%
plt.style.use('fivethirtyeight') #cambia el estilo de todos los graficos

fig, axs = plt.subplots(ncols=2, nrows=1)
ax1 = axs[0]
ax2 = axs[1]
ax1.plot(df['etiquetas'], df['cantidad'])
ax2.pie(df['cantidad']);

# %%
plt.style.use('dark_background') #cambia el estilo de todos los graficos

fig, axs = plt.subplots(ncols=2, nrows=1)
ax1 = axs[0]
ax2 = axs[1]
ax1.plot(df['etiquetas'], df['cantidad'])
ax2.pie(df['cantidad']);
